# %%
import csv
import numpy as np

with open('test_relu.csv', newline='', ) as csvfile:
    reader = csv.reader(csvfile)

    progress = []
    timings = []

    for row in reader:
        progress.append(float(row[0]))
        timings.append(float(row[1]))

    progress = np.array_split(progress[1:], 33)
    timings = np.array_split(timings[1:], 33)

# %%
totalTimes = []
for times in timings:
	totalTimes.append(sum(times))

timeMean = np.mean(totalTimes)
print("Average time per run:", timeMean)
print("variance in time per run:", np.var(totalTimes))

d = 1.96 * np.sqrt(np.var(totalTimes)/33)
confidenceInterval = [timeMean - d, timeMean + d]

print("Confidence interval for time:", confidenceInterval)
# Out:
# Average time per run: 89.69342361074506
# variance in time per run: 0.1398757255114465
# Confidence interval for time: [89.56581785102837, 89.82102937046174]

# %%
totalProgress = []
for prog in progress:
	totalProgress.append(prog[-1])

print(len(totalProgress))
print(totalProgress)

progMean = np.mean(totalProgress)
print("Average prog per run:", progMean)
print("variance in time per run:", np.var(totalProgress))

d = 1.96 * np.sqrt(np.var(totalProgress)/33)
confidenceInterval = [progMean - d, progMean + d]

print("Confidence interval for time:", confidenceInterval)
# Out:
# 33
# [0.8605, 0.7711, 0.7121, 0.7595, 0.7866, 0.8458, 0.6387, 0.8368, 0.844, 0.7361, 0.8425, 0.7947, 0.7927, 0.8431, 0.8487, 0.6678, 0.753, 0.8213, 0.763, 0.6834, 0.8483, 0.6616, 0.6928, 0.845, 0.7033, 0.7669, 0.8498, 0.8442, 0.8386, 0.7001, 0.8213, 0.7609, 0.6756]
# Average prog per run: 0.7760545454545453
# variance in time per run: 0.004564911570247934
# Confidence interval for time: [0.7530021911487847, 0.7991068997603059]

# %%
import matplotlib.pyplot as plt

chartData = []
for prog in progress:
	chartData

plt.plot(totalProgress)
plt.show()
